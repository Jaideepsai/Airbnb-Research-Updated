# %%
# Scrapping works only for images from AIrbnb http://insideairbnb.com/get-the-data.html excel
import pandas as pd
import numpy as np
data=pd.read_csv('/Users/jaideep/Desktop/Airbnb/Airbnb_Full_Project_Files_1/truncated_for_occupancy365.csv')
df = pd.DataFrame(data)
df
# Out:
#             id  indoor  outdoor  total_images  host_acceptance_rate  \
# 0         2818      28        0            28                   NaN
# 1         3209      32       18            50                   NaN
# 2        20168      24        0            24                   NaN
# 3        25428      18        0            18                   NaN
# 4        25488      34        2            36                   NaN
# 5        27886      19        5            24                   NaN
# 6        28658      17        0            17                   NaN
# 7        28871       2        2             4                   NaN
# 8        29051       1        1             2                   NaN
# 9        42970      17        4            21                   NaN
# 10       43980      13        3            16                   NaN
# 11       44805      12       10            22                   NaN
# 12       48076      29        5            34                   NaN
# 13       49552      21       18            39                   NaN
# 14       50523      10        7            17                   NaN
# 15       50570      18        0            18                   NaN
# 16       52490      16        2            18                   NaN
# 17       53671      28        6            34                   NaN
# 18       55709      24       24            48                   NaN
# 19       55807      27        3            30                   NaN
# 20       55868      13        1            14                   NaN
# 21       58211      28        2            30                   NaN
# 22       58600      34       12            46                   NaN
# 23       62015      40        2            42                   NaN
# 24       68290      34       10            44                   NaN
# 25       68873      17        3            20                   NaN
# 26       69042      10        5            15                   NaN
# 27       71231      20       13            33                   NaN
# 28       73917      26        8            34                   NaN
# 29       75382      58       60           118                   NaN
# ...        ...     ...      ...           ...                   ...
# 4376  17846988      18        4            22                   NaN
# 4377  17854840      18        0            18                   NaN
# 4378  17859181      19        9            28                   NaN
# 4379  17862359      10        0            10                   NaN
# 4380  17870073      14        5            19                   NaN
# 4381  17871596      11        3            14                   NaN
# 4382  17872586      24        0            24                   NaN
# 4383  17874329      10        0            10                   NaN
# 4384  17874552      13        1            14                   NaN
# 4385  17875133      21        9            30                   NaN
# 4386  17900191       9        4            13                   NaN
# 4387  17902223      15        0            15                   NaN
# 4388  17911838      11        3            14                   NaN
# 4389  17913851       8        2            10                   NaN
# 4390  17913931       5        0             5                   NaN
# 4391  17921065      14        7            21                   NaN
# 4392  17924907       7        2             9                   NaN
# 4393  17931425       5        1             6                   NaN
# 4394  17935451      23        8            31                   NaN
# 4395  17936064      16        8            24                   NaN
# 4396  17952544      16        3            19                   NaN
# 4397  17953351       8        4            12                   NaN
# 4398  17955592      92        5            97                   NaN
# 4399  17967583      22        2            24                   NaN
# 4400  17969022      23        4            27                   NaN
# 4401  17969025       6        2             8                   NaN
# 4402  17975252       2        0             2                   NaN
# 4403  17986807      16        3            19                   NaN
# 4404  18002212      11        1            12                   NaN
# 4405  18004933       8        2            10                   NaN
#
#       host_listings_count  host_total_listings_count  \
# 0                       1                          1
# 1                       1                          1
# 2                       2                          2
# 3                       2                          2
# 4                       2                          2
# 5                       1                          1
# 6                       2                          2
# 7                       3                          3
# 8                       3                          3
# 9                       2                          2
# 10                      1                          1
# 11                      2                          2
# 12                      2                          2
# 13                      1                          1
# 14                      1                          1
# 15                      3                          3
# 16                      1                          1
# 17                      1                          1
# 18                      3                          3
# 19                      1                          1
# 20                      1                          1
# 21                      4                          4
# 22                      1                          1
# 23                      1                          1
# 24                     10                         10
# 25                     10                         10
# 26                      2                          2
# 27                      2                          2
# 28                      1                          1
# 29                      3                          3
# ...                   ...                        ...
# 4376                    1                          1
# 4377                    1                          1
# 4378                    4                          4
# 4379                    1                          1
# 4380                    1                          1
# 4381                    1                          1
# 4382                    3                          3
# 4383                    1                          1
# 4384                    1                          1
# 4385                    1                          1
# 4386                    1                          1
# 4387                    1                          1
# 4388                    1                          1
# 4389                    1                          1
# 4390                    2                          2
# 4391                    1                          1
# 4392                    1                          1
# 4393                    1                          1
# 4394                    1                          1
# 4395                    1                          1
# 4396                    1                          1
# 4397                    1                          1
# 4398                    1                          1
# 4399                  125                        125
# 4400                    2                          2
# 4401                    2                          2
# 4402                    1                          1
# 4403                    1                          1
# 4404                    2                          2
# 4405                    2                          2
#
#       neighbourhood_group_cleansed   latitude  longitude      ...       \
# 0                              NaN  52.365753   4.941419      ...
# 1                              NaN  52.390224   4.873924      ...
# 2                              NaN  52.365086   4.893541      ...
# 3                              NaN  52.373116   4.883668      ...
# 4                              NaN  52.365009   4.943573      ...
# 5                              NaN  52.386726   4.892078      ...
# 6                              NaN  52.375343   4.857289      ...
# 7                              NaN  52.367188   4.890918      ...
# 8                              NaN  52.367725   4.891512      ...
# 9                              NaN  52.367813   4.890012      ...
# 10                             NaN  52.357456   4.861242      ...
# 11                             NaN  52.360767   4.944349      ...
# 12                             NaN  52.380421   4.894535      ...
# 13                             NaN  52.379246   4.890227      ...
# 14                             NaN  52.368408   4.884134      ...
# 15                             NaN  52.377739   4.848912      ...
# 16                             NaN  52.370045   4.938691      ...
# 17                             NaN  52.389053   4.885589      ...
# 18                             NaN  52.358955   4.897259      ...
# 19                             NaN  52.369656   4.862025      ...
# 20                             NaN  52.356133   4.885150      ...
# 21                             NaN  52.369164   4.884445      ...
# 22                             NaN  52.381802   4.868031      ...
# 23                             NaN  52.364452   4.931236      ...
# 24                             NaN  52.368870   4.895234      ...
# 25                             NaN  52.369499   4.895560      ...
# 26                             NaN  52.373528   4.876906      ...
# 27                             NaN  52.357304   4.891381      ...
# 28                             NaN  52.378944   4.890602      ...
# 29                             NaN  52.364826   4.927616      ...
# ...                            ...        ...        ...      ...
# 4376                           NaN  52.369770   4.858977      ...
# 4377                           NaN  52.343346   4.909697      ...
# 4378                           NaN  52.371414   4.938782      ...
# 4379                           NaN  52.354130   4.899206      ...
# 4380                           NaN  52.387852   4.885546      ...
# 4381                           NaN  52.368958   4.908914      ...
# 4382                           NaN  52.357151   4.890180      ...
# 4383                           NaN  52.353519   4.786250      ...
# 4384                           NaN  52.367985   4.880526      ...
# 4385                           NaN  52.370655   4.899678      ...
# 4386                           NaN  52.344845   4.860373      ...
# 4387                           NaN  52.363239   4.865704      ...
# 4388                           NaN  52.389278   4.886126      ...
# 4389                           NaN  52.373875   4.941311      ...
# 4390                           NaN  52.366581   4.844628      ...
# 4391                           NaN  52.369961   4.881438      ...
# 4392                           NaN  52.339314   4.918487      ...
# 4393                           NaN  52.378452   4.854023      ...
# 4394                           NaN  52.367485   4.908963      ...
# 4395                           NaN  52.396271   4.904650      ...
# 4396                           NaN  52.369450   4.889657      ...
# 4397                           NaN  52.352375   4.916660      ...
# 4398                           NaN  52.347221   4.858696      ...
# 4399                           NaN  52.327160   4.878619      ...
# 4400                           NaN  52.374550   4.859109      ...
# 4401                           NaN  52.351933   4.905323      ...
# 4402                           NaN  52.384624   4.873168      ...
# 4403                           NaN  52.356339   4.892472      ...
# 4404                           NaN  52.370728   4.865133      ...
# 17                        0  matched (3)   12      1     1      1.434939
# 18                       12  matched (3)   12      1     1      1.270064
# 19                       13  matched (3)   12      1     1      0.886111
# 20                       12  matched (3)   12      1     1      0.359423
# 21                        0  matched (3)   12      1     1      0.551428
# 22                        0  matched (3)   12      1     1      1.152973
# 23                        0  matched (3)   12      1     1      1.539774
# 24                       22  matched (3)   12      1     1      1.522904
# 25                       20  matched (3)   12      1     1      1.732899
# 26                       13  matched (3)   12      1     1      1.100685
# 27                        0  matched (3)   12      1     1      0.901103
# 28                       19  matched (3)   12      1     1      1.053731
# 29                        0  matched (3)   12      1     1      0.604716
# ...                     ...          ...  ...    ...   ...           ...
# 4376                     20  matched (3)   12      1     1      0.991962
# 4377                      0  matched (3)   12      1     1      0.867990
# 4378                     28  matched (3)   12      1     1      0.521240
# 4379                     10  matched (3)   12      1     1      0.883500
# 4380                      0  matched (3)   12      1     1      0.613347
# 4381                      0  matched (3)   12      1     1      0.613853
# 4382                     24  matched (3)   12      1     1      0.978822
# 4383                      0  matched (3)   12      1     1      1.316556
# 4384                      0  matched (3)   12      1     1      0.774738
# 4385                      0  matched (3)   12      1     1      1.024992
# 4386                     13  matched (3)   12      1     1      1.217083
# 4387                      0  matched (3)   12      1     1      0.411481
# 4388                      0  matched (3)   12      1     1      0.497101
# 4389                      0  matched (3)   12      1     1      1.230016
# 4390                      0  matched (3)   12      1     1      1.355653
# 4391                      0  matched (3)   12      1     1      1.613446
# 4392                      0  matched (3)   12      1     1      0.645312
# 4393                      0  matched (3)   12      1     1      0.932239
# 4394                     31  matched (3)   12      1     1      0.438586
# 4395                     24  matched (3)   12      1     1      0.985529
# 4396                     19  matched (3)   12      1     1      1.671782
# 4397                      0  matched (3)   12      1     1      0.636116
# 4398                      0  matched (3)   12      1     1      0.906210
# 4399                      0  matched (3)   12      1     1      0.886699
# 4400                      0  matched (3)   12      1     1      1.114011
# 4401                      0  matched (3)   12      1     1      1.253795
# 4402                      0  matched (3)   12      1     1      0.740074
# 4403                      0  matched (3)   12      1     1      1.188457
# 4404                      0  matched (3)   12      1     1      0.687234
# 4405                      0  matched (3)   12      1     1      0.881681
#
# [4406 rows x 92 columns]

# %%
import urllib
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import os
import time

# %%
#works in mac only and only for airbnb listings url 
#scrapped images from  the slide show for each airbnb listing
options = webdriver.ChromeOptions()
options.binary_location = '/Applications/Google Chrome Canary.app/Contents/MacOS/Google Chrome Canary'
options.add_argument('window-size=800x841')
options.add_argument('headless')
driver = webdriver.Chrome(chrome_options=options)
sum_total=0
count_listings=0
d=[];e=[];f=[];
for row in df.itertuples():
    #print(row[1])
    data_url='https://www.airbnb.com/rooms/'+str(row[1])
    time.sleep(np.random.randint(1,10))
    driver.get(data_url)
    try:
        time.sleep(np.random.randint(1,2))
        #class keeps updating in airbnb site need to check constantly
        driver.find_element_by_css_selector('._1s8f7pz').click()
        verified=driver.find_element_by_css_selector('._dxgq4v')
        try:
            verified.find_element_by_css_selector('.text-muted')
            d.append("1")
            e.append(str(row[1]))
        except:
            d.append("0")
            e.append(str(row[1]))
            
    except NoSuchElementException:
        print data_url + " listing is no longer available."
driver.close()
# Out:
# https://www.airbnb.com/rooms/170223 listing is no longer available.
# https://www.airbnb.com/rooms/193081 listing is no longer available.
# https://www.airbnb.com/rooms/270839 listing is no longer available.
